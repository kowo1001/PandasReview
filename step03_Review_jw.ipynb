# %%
import pandas as pd
df1 = pd.read_csv('0.dataSet/avg18.07.csv')

df1.head(20)
# Out:
#    지역명               규모구분    연도   월 분양가격(㎡)
# 0   서울                 전체  2015  10    5841
# 1   서울         전용면적 60㎡이하  2015  10    5652
# 2   서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3   서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4   서울        전용면적 102㎡초과  2015  10    5879
# 5   인천                 전체  2015  10    3163
# 6   인천         전용면적 60㎡이하  2015  10    3488
# 7   인천   전용면적 60㎡초과 85㎡이하  2015  10    3119
# 8   인천  전용면적 85㎡초과 102㎡이하  2015  10    3545
# 9   인천        전용면적 102㎡초과  2015  10    3408
# 10  경기                 전체  2015  10    3138
# 11  경기         전용면적 60㎡이하  2015  10    3126
# 12  경기   전용면적 60㎡초과 85㎡이하  2015  10    3239
# 13  경기  전용면적 85㎡초과 102㎡이하  2015  10    3496
# 14  경기        전용면적 102㎡초과  2015  10    3680
# 15  부산                 전체  2015  10    3112
# 16  부산         전용면적 60㎡이하  2015  10    2950
# 17  부산   전용면적 60㎡초과 85㎡이하  2015  10    2999
# 18  부산  전용면적 85㎡초과 102㎡이하  2015  10    2957
# 19  부산        전용면적 102㎡초과  2015  10    3500

# %%
# axis = 1 세로(열) / axis = 0 가로(행)

# %%
df1.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)'], dtype='object')

# %%
df1['분양가격'] = pd.to_numeric(df1['분양가격(㎡)'], errors='coerce')

# %%
# 전체 분양가격 평균
import numpy as np

np.mean(df1['분양가격'])
# Out:
# 3063.2972159518436

# %%
# 지역별 검색
groupby_location = data.groupby('지역명')
groupby_location

# %%
for key, value in groupby_location:
    print(key, ' - ', value)
    print('=' * 20)
# Out:
# 강원  -       지역명               규모구분    연도   월 분양가격(㎡)
# 45    강원                 전체  2015  10    2167
# 46    강원         전용면적 60㎡이하  2015  10    2286
# 47    강원   전용면적 60㎡초과 85㎡이하  2015  10    2212
# 48    강원  전용면적 85㎡초과 102㎡이하  2015  10    2061
# 49    강원        전용면적 102㎡초과  2015  10    2171
# ...   ..                ...   ...  ..     ...
# 2850  강원                 전체  2018   7    2312
# 2851  강원         전용면적 60㎡이하  2018   7    2284
# 2852  강원   전용면적 60㎡초과 85㎡이하  2018   7    2309
# 2853  강원  전용면적 85㎡초과 102㎡이하  2018   7    2864
# 2854  강원        전용면적 102㎡초과  2018   7    2665
#
# [170 rows x 5 columns]
# ...
# 경기  -       지역명               규모구분    연도   월 분양가격(㎡)
# 10    경기                 전체  2015  10    3138
# 11    경기         전용면적 60㎡이하  2015  10    3126
# 12    경기   전용면적 60㎡초과 85㎡이하  2015  10    3239
# 13    경기  전용면적 85㎡초과 102㎡이하  2015  10    3496
# 14    경기        전용면적 102㎡초과  2015  10    3680
# ...   ..                ...   ...  ..     ...
# ...

# %%
df2 = pd.read_csv('0.dataSet/avg15.09.csv', encoding='utf-8', thousands=',')
df2 = df2.fillna('')

# %%
col = list(df2.iloc[2])

for i in range(2, len(col)-3):
    if i == 2:
        col[2] = '2013년 12월'
    elif i // 15 == 0:
        col[i] = '2014년 ' + col[i]
    else:
        col[i] = '2015년 ' + col[i]

df2.columns = col
df3 = df2.drop([0,1,2])
df3
# Out:
#        시도 시군구 2013년 12월 2014년 1월 2014년 2월 2014년 3월 2014년 4월 2014년 5월 2014년 6월  \
# 3      전국         8,059    8,130    8,195    8,204    8,289    8,358    8,344
# 4      서울        18,189   17,925   17,925   18,016   18,098   19,446   18,867
# 5   6대광역시  부산     8,111    8,111    9,078    8,965    9,402    9,501    9,453
# 6          대구     8,080    8,080    8,077    8,101    8,267    8,274    8,360
# 7          인천    10,204   10,204   10,408   10,408   10,000    9,844   10,058
# 8          광주     6,098    7,326    7,611    7,346    7,346    7,523    7,659
# 9          대전     8,321    8,321    8,321    8,341    8,341    8,341    8,333
# 10         울산     8,090    8,090    8,090    8,153    8,153    8,153    8,153
# 11                8,151    8,355    8,597    8,552    8,585    8,606    8,669
# 12     경기        10,855   10,855   10,791   10,784   10,876   10,646   10,266
# 13    수도권        13,083   12,995   13,041   13,069   12,991   13,312   13,064
# ...

# %%
df4 = pd.read_csv('0.dataSet/avg15.09.csv', encoding='utf-8', thousands=',')
df4 = df4.fillna('')

df4.columns = df4.loc[1] + df4.loc[2]
df4.columns 
df4 = df4.loc[3:]
df4
# Out:
#      구분시도 시군구 2013년12월 2014년1월      2월      3월      4월      5월      6월  \
# 3      전국        8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 4      서울       18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 5   6대광역시  부산    8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 6          대구    8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 7          인천   10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 8          광주    6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 9          대전    8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 10         울산    8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 11               8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 12     경기       10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 13    수도권       13,083  12,995  13,041  13,069  12,991  13,312  13,064
# 14     세종        7,601   7,600   7,532   7,814   7,908   7,934   8,067
# ...

# %%
df4.columns
# Out:
# Index(['구분시도', '시군구', '2013년12월', '2014년1월', '2월', '3월', '4월', '5월', '6월',
#        '7월', '8월', '9월', '10월', '11월', '12월', '2015년1월', '2월', '3월', '4월',
#        '5월', '6월', '7월', '8월', '9월', '전월비', '전년말비', '(단위: 천원/3.3㎡)전년동월비'],
#       dtype='object')

# %%
df2.columns = ['구분시도','시군구', '2013년12월', '2014년1월', '2014년2월','2014년3월','2014년4월','2014년5월','2014년6월','2014년7월','2014년8월','2014년9월','2014년10월','2014년11월','2014년12월','2015년1월','2015년2월','2015년3월','2015년4월','2015년5월','2015년6월','2015년7월','2015년8월','2015년9월','전월비','전년말비','(단위: 천원/3.3㎡)전년동월비']
df2
# Out:
#      구분시도 시군구 2013년12월 2014년1월 2014년2월 2014년3월 2014년4월 2014년5월 2014년6월  \
# 3      전국        8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 4      서울       18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 5   6대광역시  부산    8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 6          대구    8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 7          인천   10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 8          광주    6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 9          대전    8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 10         울산    8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 11               8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 12     경기       10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 13    수도권       13,083  12,995  13,041  13,069  12,991  13,312  13,064
# 14     세종        7,601   7,600   7,532   7,814   7,908   7,934   8,067
# ...

# %%
def toInt(a):
    return a.replace(',','')

# %%
del df2['시군구']
del df2['구분시도']

# string type을 int type으로 변환
for i in df2:
    df2[i] = df2[i].apply(toInt)
    
type(df2.values[0][0])
# Out:
# numpy.int64

# %%
df2
# Out:
#     2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  2014년7월  \
# 3       8059     8130     8195     8204     8289     8358     8344     8333
# 4      18189    17925    17925    18016    18098    19446    18867    18742
# 5       8111     8111     9078     8965     9402     9501     9453     9457
# 6       8080     8080     8077     8101     8267     8274     8360     8360
# 7      10204    10204    10408    10408    10000     9844    10058     9974
# 8       6098     7326     7611     7346     7346     7523     7659     7612
# 9       8321     8321     8321     8341     8341     8341     8333     8333
# 10      8090     8090     8090     8153     8153     8153     8153     8153
# 11      8151     8355     8597     8552     8585     8606     8669     8648
# 12     10855    10855    10791    10784    10876    10646    10266    10124
# 13     13083    12995    13041    13069    12991    13312    13064    12947
# ...

# %%
df2.columns
# Out:
# Index(['구분시도', '시군구', '2013년12월', '2014년1월', '2월', '3월', '4월', '5월', '6월',
#        '7월', '8월', '9월', '10월', '11월', '12월', '2015년1월', '2월', '3월', '4월',
#        '5월', '6월', '7월', '8월', '9월', '전월비', '전년말비', '(단위: 천원/3.3㎡)전년동월비'],
#       dtype='object')

# %%
type(df2.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890 entries, 0 to 2889
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      2890 non-null   object
#  1   규모구분     2890 non-null   object
#  2   연도       2890 non-null   int64
#  3   월        2890 non-null   int64
#  4   분양가격(㎡)  2750 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 113.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   □ 평균 분양가격    24 non-null     object
#  1   Unnamed: 1   24 non-null     object
#  2   Unnamed: 2   24 non-null     object
#  3   Unnamed: 3   24 non-null     object
#  4   Unnamed: 4   24 non-null     object
#  5   Unnamed: 5   24 non-null     object
#  6   Unnamed: 6   24 non-null     object
#  7   Unnamed: 7   24 non-null     object
#  8   Unnamed: 8   24 non-null     object
#  9   Unnamed: 9   24 non-null     object
#  10  Unnamed: 10  24 non-null     object
#  11  Unnamed: 11  24 non-null     object
#  12  Unnamed: 12  24 non-null     object
#  13  Unnamed: 13  24 non-null     object
#  14  Unnamed: 14  24 non-null     object
#  15  Unnamed: 15  24 non-null     object
#  16  Unnamed: 16  24 non-null     object
#  17  Unnamed: 17  24 non-null     object
# ...

# %%
# index 0 제거
df3 = df2.drop([0])
df3
# Out:
#    평균 분양가격                                                               \
# 1       구분        2013년   2014년
# 2       시도  시군구     12월      1월      2월      3월      4월      5월      6월
# 3       전국        8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 4       서울       18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 5    6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 6            대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 7            인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 8            광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 9            대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 10           울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 11                8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 12      경기       10,855  10,855  10,791  10,784  10,876  10,646  10,266
# 13     수도권       13,083  12,995  13,041  13,069  12,991  13,312  13,064
# ...

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of    평균 분양가격                                                               \
# 1       구분        2013년   2014년
# 2       시도  시군구     12월      1월      2월      3월      4월      5월      6월
# 3       전국        8,059   8,130   8,195   8,204   8,289   8,358   8,344
# 4       서울       18,189  17,925  17,925  18,016  18,098  19,446  18,867
# 5    6대광역시   부산   8,111   8,111   9,078   8,965   9,402   9,501   9,453
# 6            대구   8,080   8,080   8,077   8,101   8,267   8,274   8,360
# 7            인천  10,204  10,204  10,408  10,408  10,000   9,844  10,058
# 8            광주   6,098   7,326   7,611   7,346   7,346   7,523   7,659
# 9            대전   8,321   8,321   8,321   8,341   8,341   8,341   8,333
# 10           울산   8,090   8,090   8,090   8,153   8,153   8,153   8,153
# 11                8,151   8,355   8,597   8,552   8,585   8,606   8,669
# 12      경기       10,855  10,855  10,791  10,784  10,876  10,646  10,266
# ...
